# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
Budget_data=pd.read_excel(r'C:\Users\dell\Desktop\data sets\Budget Sales data\Budget Sales data\budget.xlsx')


Budget_data = Budget_data.iloc[2: , :]
Budget_data.columns = Budget_data.iloc[0]
Budget_data = Budget_data[1:]
Budget_data.index=range(1,22)
Budget_data.head()
# Out:
# 2     Category        Subcategory             ProductName ProductKey  \
# 1  Accessories         Bike Racks     Hitch Rack - 4-Bike        483
# 2  Accessories        Bike Stands  All-Purpose Bike Stand        486
# 3  Accessories  Bottles and Cages   Water Bottle - 30 oz.        477
# 4  Accessories           Cleaners   Bike Wash - Dissolver        484
# 5  Accessories            Fenders   Fender Set - Mountain        485
#
# 2 Jan, 2016 Feb, 2016 Mar, 2016 Apr, 2016 May, 2016 Jun, 2016 Jul, 2016  \
# 1      1131      2635      4134      2179      2637      3279      2218
# 2       666      3695      2868      4862      3439      4612      2774
# 3      1892      4727      3656      4449      4051      6257      4871
# 4       160       713       555       656       369       582       777
# 5       970      3014      2809      4259      3638      3721      4190
#
# 2 Aug, 2016 Sep, 2016 Oct, 2016 Nov, 2016 Dec, 2016 Grand Total
# ...

# %%
df_database=pd.read_excel(r'C:\Users\dell\Desktop\data sets\Budget Sales data\Budget Sales data\AdventureWorks_database.xlsx')
df_database.head()
df_database.shape
df_database.head()
# Out:
#         Date   DateKey  Year Quarter  MonthNum Month FiscalYear FiscalQuarter  \
# 0 2016-04-03  20160403  2016      Q2         4   Apr     FY2016           FQ4
# 1 2016-04-04  20160404  2016      Q2         4   Apr     FY2016           FQ4
# 2 2016-04-05  20160405  2016      Q2         4   Apr     FY2016           FQ4
# 3 2016-04-06  20160406  2016      Q2         4   Apr     FY2016           FQ4
# 4 2016-04-07  20160407  2016      Q2         4   Apr     FY2016           FQ4
#
#    FiscalMonthNum FiscalMonth MonthYear MonthYearLong  MonthYearNum  \
# 0              10         Apr    Apr-16      Apr-2016        201604
# 1              10         Apr    Apr-16      Apr-2016        201604
# 2              10         Apr    Apr-16      Apr-2016        201604
# 3              10         Apr    Apr-16      Apr-2016        201604
# 4              10         Apr    Apr-16      Apr-2016        201604
#
#    WeekdayNum Weekday WeekdayWeekend
# 0           1     Sun        Weekend
# ...

# %%
Sales_data=pd.read_excel(r'C:\Users\dell\Desktop\data sets\SalesData.xlsx')
Sales_data.head()
# Out:
#    ProductKey  OrderDate   ShipDate  CustomerKey  PromotionKey  \
# 0         310 2014-01-01 2014-01-08        21768             1
# 1         346 2014-01-01 2014-01-08        28389             1
# 2         346 2014-01-01 2014-01-08        25863             1
# 3         336 2014-01-01 2014-01-08        14501             1
# 4         346 2014-01-01 2014-01-08        11003             1
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  OrderQuantity  \
# 0                  6          SO43697                     1              2
# 1                  7          SO43698                     1              2
# 2                  1          SO43699                     1              2
# 3                  4          SO43700                     1              2
# 4                  9          SO43701                     1              2
#
#    UnitPrice  TotalProductCost  SalesAmount    TaxAmt
# 0  1789.1350         2171.2942    3578.2700  286.2616
# ...

# %%
Customer_data=pd.read_excel(r'C:\Users\dell\Desktop\data sets\Customer_Data.xlsx')
Customer_data.head()
# Out:
#    CustomerKey First Name Last Name            FullName  BirthDate  \
# 0        11001     Eugene     Huang       Huang, Eugene 1965-05-14
# 1        11002      Ruben    Torres       Torres, Ruben 1965-08-12
# 2        11003    Christy       Zhu        Zhu, Christy 1968-02-15
# 3        11004  Elizabeth   Johnson  Johnson, Elizabeth 1968-08-08
# 4        11005      Julio      Ruiz         Ruiz, Julio 1965-08-05
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             S      M         60000              3                     3
# 1             M      M         60000              3                     3
# 2             S      F         70000              0                     0
# 3             S      F         80000              5                     5
# 4             S      M         70000              0                     0
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned  \
# ...

# %%
Product_data=pd.read_excel(r'C:\Users\dell\Desktop\data sets\Productdata.xlsx')
Product_data.head()
# Out:
#    ProductKey            ProductName SubCategory Category  StandardCost Color  \
# 0           1        Adjustable Race         NaN      NaN           NaN   NaN
# 1           2           Bearing Ball         NaN      NaN           NaN   NaN
# 2           3        BB Ball Bearing         NaN      NaN           NaN   NaN
# 3           4  Headset Ball Bearings         NaN      NaN           NaN   NaN
# 4           5                  Blade         NaN      NaN           NaN   NaN
#
#    ListPrice  DaysToManufacture ProductLine ModelName  \
# 0        NaN                  0         NaN       NaN
# 1        NaN                  0         NaN       NaN
# 2        NaN                  1         NaN       NaN
# 3        NaN                  0         NaN       NaN
# 4        NaN                  1         NaN       NaN
#
#                                                Photo ProductDescription  \
# 0  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# ...

# %%
Territory_data=pd.read_excel(r'C:\Users\dell\Desktop\data sets\TerritoryData.xlsx')
Territory_data.head()
# Out:
#    SalesTerritoryKey     Region        Country          Group  \
# 0                  1  Northwest  United States  North America
# 1                  2  Northeast  United States  North America
# 2                  3    Central  United States  North America
# 3                  4  Southwest  United States  North America
# 4                  5  Southeast  United States  North America
#
#                                          RegionImage
# 0  http://www.avising.com/me/LearnPBI/DataSources...
# 1  http://www.avising.com/me/LearnPBI/DataSources...
# 2  http://www.avising.com/me/LearnPBI/DataSources...
# 3  http://www.avising.com/me/LearnPBI/DataSources...
# 4  http://www.avising.com/me/LearnPBI/DataSources...

# %%
df=pd.merge(Sales_data,Customer_data,on='CustomerKey')

# %%
df=pd.merge(df,Product_data,on='ProductKey')

# %%
df=pd.merge(df,Territory_data,on='SalesTerritoryKey')

# %%
df
df.columns
df.drop(columns =['ProductKey','SalesTerritoryKey','SalesOrderNumber','SalesOrderLineNumber','TotalProductCost','TaxAmt','First Name','Last Name','FullName','AddressLine1','DaysToManufacture','Photo','Region','Group','RegionImage','StartDate'],axis=1,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58181 entries, 0 to 58180
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             58181 non-null  datetime64[ns]
#  1   ShipDate              58181 non-null  datetime64[ns]
#  2   CustomerKey           58181 non-null  int64
#  3   PromotionKey          58181 non-null  int64
#  4   OrderQuantity         58181 non-null  int64
#  5   UnitPrice             58181 non-null  float64
#  6   SalesAmount           58181 non-null  float64
#  7   BirthDate             58181 non-null  datetime64[ns]
#  8   MaritalStatus         58181 non-null  object
#  9   Gender                58181 non-null  object
#  10  YearlyIncome          58181 non-null  int64
#  11  TotalChildren         58181 non-null  int64
#  12  NumberChildrenAtHome  58181 non-null  int64
#  13  Education             58181 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# OrderDate                   0
# ShipDate                    0
# CustomerKey                 0
# PromotionKey                0
# OrderQuantity               0
# UnitPrice                   0
# SalesAmount                 0
# BirthDate                   0
# MaritalStatus               0
# Gender                      0
# YearlyIncome                0
# TotalChildren               0
# NumberChildrenAtHome        0
# Education                   0
# Occupation                  0
# HouseOwnerFlag              0
# NumberCarsOwned             0
# DateFirstPurchase           0
# CommuteDistance             0
# ProductName                 0
# SubCategory                 0
# Category                    0
# StandardCost                0
# Color                   27439
# ListPrice                   0
# ProductLine                 0
# ModelName                   0
# ProductDescription          0
# Country                     0
# dtype: int64

# %%
df.drop('Color',axis=1,inplace=True)
df.isnull().sum()
# Out:
# OrderDate               0
# ShipDate                0
# CustomerKey             0
# PromotionKey            0
# OrderQuantity           0
# UnitPrice               0
# SalesAmount             0
# BirthDate               0
# MaritalStatus           0
# Gender                  0
# YearlyIncome            0
# TotalChildren           0
# NumberChildrenAtHome    0
# Education               0
# Occupation              0
# HouseOwnerFlag          0
# NumberCarsOwned         0
# DateFirstPurchase       0
# CommuteDistance         0
# ProductName             0
# SubCategory             0
# Category                0
# StandardCost            0
# ListPrice               0
# ProductLine             0
# ModelName               0
# ProductDescription      0
# Country                 0
# dtype: int64

# %% [markdown]
# #### the data now contains no missing values

# %%
df.head(3)
df.columns
# Out:
# Index(['OrderDate', 'ShipDate', 'CustomerKey', 'PromotionKey', 'OrderQuantity',
#        'UnitPrice', 'SalesAmount', 'BirthDate', 'MaritalStatus', 'Gender',
#        'YearlyIncome', 'TotalChildren', 'NumberChildrenAtHome', 'Education',
#        'Occupation', 'HouseOwnerFlag', 'NumberCarsOwned', 'DateFirstPurchase',
#        'CommuteDistance', 'ProductName', 'SubCategory', 'Category',
#        'StandardCost', 'ListPrice', 'ProductLine', 'ModelName',
#        'ProductDescription', 'Country'],
#       dtype='object')

# %%
Gender=df['Gender'].value_counts()
Marital_status=df['MaritalStatus'].value_counts()
Marital_status
TotalChildren=df['TotalChildren'].value_counts()
TotalChildren
# Out:
# TotalChildren
# 0    16474
# 2    11879
# 1    11229
# 4     7367
# 3     6813
# 5     4419
# Name: count, dtype: int64

# %%
## Plotting the pie charts to know whatis the proportion of customers accoring to marital status , Gender and how many total children they have 

figure,(ax1,ax2,ax3)=plt.subplots(ncols=3,figsize=(14,10))
ax1.set_title('Gender')
ax1.pie(Gender,labels=['male','female'],autopct='%0.0f%%',explode=[0,0.1],colors=['yellow', 'cyan'],shadow=True)
ax2.set_title('Marital Status')
ax2.pie(Marital_status,labels=['Married','Single'],autopct='%0.0f%%',explode=[0,0.1],colors=['magenta', 'lime'],shadow=True)
ax3.set_title('Total Children')
ax3.pie(TotalChildren,labels=[0,1,2,3,4,5],autopct='%0.0f%%',colors=['#FFD700',
'#FF5733','#FFC300','#C70039','#900C3F','#FF5733' ],shadow='True',explode=[0,0.1,0,0.1,0,0.1])
plt.show()

# %% [markdown]
# ### There are equal males and female customers but are more married customers with 0 children

# %%
Education=df['Education'].value_counts()
Occupation=df['Occupation'].value_counts()

Occupation
# Out:
# Occupation
# Professional      18350
# Skilled Manual    13636
# Management        10175
# Clerical           9315
# Manual             6705
# Name: count, dtype: int64

# %%
### now to understand the proportion of different customers accoring to the education  occupation and yearly income

figure,(ax1,ax2)=plt.subplots(ncols=2,figsize=(14,8))
ax1.set_title('Education')
ax1.pie(Education,labels=['Bacheolers','Partial College','Graduate College','High School','Partial HighSchool'],autopct='%0.0f%%',colors=['#FFD700','#FF5733','#FFC300','#C70039','#900C3F' ],shadow='True',explode=[0,0.1,0,0.1,0])
plt.title('Occupation')
ax2.pie(Occupation,labels=['Professional','Skilled Manual','Management','Clerical','Manual'],autopct='%0.0f%%',colors=['#FFD700','#FF5733','#FFC300','#C70039','#900C3F' ],shadow='True',explode=[0,0.1,0,0.1,0])
plt.show()

# %% [markdown]
# ### This shows that the most customers are form professional background and with a bachloers education

# %%
Income=df['YearlyIncome'].value_counts()

# %%
plt.figure(figsize=(13,5))
sns.countplot(x='YearlyIncome',data=df)
plt.title('Yearly Income',fontsize=20)
plt.show()

# %% [markdown]
# ### The most customers are those who have annula salaries 35000-70000 while customer with 50000 are less cutsomers

# %%
Category=df.Category.value_counts()
df.SubCategory.value_counts()
Category
# Out:
# Category
# Accessories    34315
# Bikes          15202
# Clothing        8664
# Name: count, dtype: int64

# %%
### plot showing the different proportion of categories and subcategories buyied
plt.title('Category of Products',fontsize=20)
plt.pie(Category,labels=['Accessories','Bikes ','Clothing'],autopct='%0.0f%%',colors=['yellow', 'cyan','Lime'],explode=[0,0.1,0.05,],shadow=True)
plt.show()

# %% [markdown]
# ### This shows that the 59% of the purchase of accessories

# %%
plt.figure(figsize=(15,5))
plt.title('SubCategory of Products')
sns.countplot(x='SubCategory',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Tyres and Tubes are purchases the most followed by the Road Bikes and the lest sold category of product is Bike stands

# %%
# Evaluating relationship between Country and no of customers by ploting bar graph

plt.figure(figsize=(10,8))
sns.set_style('darkgrid')
plt.title('Count of cutomers by Country',fontsize=20)
sns.countplot(x='Country',data=df)
sns.set_context("paper", font_scale=1.2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### the most number of the customers comes from the U.S

# %%
Country=df['Country'].value_counts()
Sales_Country=df.groupby('Country')['SalesAmount'].sum().reset_index().sort_values(by='SalesAmount',ascending=False)
plt.figure(figsize=(10, 6))
plt.bar(Sales_Country['Country'], Sales_Country['SalesAmount'],color='teal')
plt.title('Total Sales Amount by Country',fontsize=20)
plt.xlabel('Country')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### According to the plot we know that the most amount of sales comes from U.S and though the number of customers in Canada is more the amount is less

# %%
df['Year']=df['OrderDate'].dt.year
Yealry_sales=df.groupby('Year')['SalesAmount'].sum().reset_index()
df['Month']=df['OrderDate'].dt.month
Month_sales=df.groupby('Month')['SalesAmount'].sum().reset_index()

# %%
## Plotting the graph for the total sales by year and month

sns.barplot(x='Year',y='SalesAmount',data=Yealry_sales)
plt.title('Yearly total Sales',fontsize=20)
plt.show()
# Out:
# Text(0.5, 1.0, 'Yearly total Sales')

# %% [markdown]
# ### The most sales are done in the year 2016

# %%
plt.figure(figsize=(15,5))

sns.barplot(x='Month',y='SalesAmount',data=Month_sales)
plt.title('Monthly Total Sales Amount Data',fontsize=20)
plt.show()
# Out:
# Text(0.5, 1.0, 'Monthly Sales Data')

# %% [markdown]
# ### the most amount comes in the month of December , november and june and it gradually increases from Jan to Dec

# %%
## the plot of the total sales proportion made by customers accoring to their marital status
Sales_maritalstatus=df.groupby('MaritalStatus')['SalesAmount'].sum()
Sales_maritalstatus.plot(kind='pie',autopct='%0.0f%%',colors=['teal','Cyan'],shadow=True,labels=['Married','Single'])
plt.title(' Total Sales Amount accoridng to marital status',fontsize=19)
# Out:
# Text(0.5, 1.0, 'Sales Amount accoridng to marital status')

# %% [markdown]
# ### This plot shows that the Married people spends more amount

# %%
Sales_gender=df.groupby('Gender')['SalesAmount'].sum()
Sales_gender.plot(kind='pie',autopct='%0.0f%%',colors=['teal','Cyan'],shadow=True,labels=['female','Male'])
plt.title('Total Sales amount according to Gender',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales amount according to Gender')

# %% [markdown]
# ### The plot shows that the male and females spennds almost equal amount of money

# %%
Sales_income=df.groupby('YearlyIncome')['SalesAmount'].sum()
plt.figure(figsize=(14,6))
Sales_income.plot(kind='line')
plt.title('Total Sales According to Cutomers Income',fontsize=20)
plt.show()

# %% [markdown]
# ### the above plot shows that the most customers are with a anual income of range between 35000 - 80000 and aslo the most amount from the same customers

# %%
Sales_Occupation=df.groupby('Occupation')['SalesAmount'].sum()
Sales_Occupation.plot(kind='pie',autopct='%0.0f%%',shadow=True)
plt.title(' Total Sales according to Occupation',fontsize=20)
plt.show()

# %% [markdown]
# ### This shows that the more money comes from the customers with a job at professional level

# %%
Sales_TotalChildren=df.groupby('TotalChildren')['SalesAmount'].sum()
Sales_TotalChildren.plot(kind='pie',autopct='%0.0f%%',shadow=True)
plt.title('Sales amount according to the Total Children of the customers',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales amount according to the Total Children of the customers')

# %% [markdown]
# ### this shows that most of the amount comes from the customers with 0 childrens followed by customers with 1 child

# %%
Sales_Education=df.groupby('Education')['SalesAmount'].sum()
Sales_Education.plot(kind='pie',autopct='%0.0f%%',shadow=True)
plt.title('Sales according to Education',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales according to Education')

# %% [markdown]
# ### This shows that the customrs with  bachloers degree spends the most amount of money while thos who have a partial High school speends lesat amount of money

# %%
Sales_Category=df.groupby('Category')['SalesAmount'].sum()
Sales_Category.plot(kind='pie',autopct='%0.0f%%',shadow=True)
plt.title('Sales according to Category',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales according to Category')

# %% [markdown]
# ### This shows that the Bikes brings the most amount of money while the proportion of cloting and accessiries is very less

# %%
Sales_SubCategory=df.groupby('SubCategory')['SalesAmount'].sum()
Sales_SubCategory.plot(kind='bar')
plt.title('Sales according to SubCategory',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales according to SubCategory')

# %% [markdown]
# ### This plot shows that the Road Bikes brings the most amount followed by  the Mountain Bikes Though the Tires and tubes are purchased the most the amount is less

# %%
### extracting age from the Birthdate columns of the data
from datetime import datetime 
from dateutil.relativedelta import relativedelta

current_date=datetime.now()
current_date
# Out:
# datetime.datetime(2024, 5, 10, 12, 56, 44, 188229)

# %%
df['Age'] = df['BirthDate'].apply(lambda x: relativedelta(current_date, x).years)
# Out:
# 0        77
# 1        50
# 2        62
# 3        56
# 4        52
#          ..
# 58176    75
# 58177    62
# 58178    57
# 58179    65
# 58180    75
# Name: Age, Length: 58181, dtype: int64

# %%
### Grouping the age in categories for analysis

def Age(years):
    if years<20:
        return 'Teen'
    elif years >20 and years <40:
        return 'Young'
    elif years >40 and years<60:
        return 'Adult'
    else:
        return 'Old'
x=df.loc[113,'Age']
Age(x)
df['AgeCategory']=df['Age'].apply(Age)
df['AgeCategory']
# Out:
# 0          Old
# 1        Adult
# 2          Old
# 3        Adult
# 4        Adult
#          ...
# 58176      Old
# 58177      Old
# 58178    Adult
# 58179      Old
# 58180      Old
# Name: AgeCategory, Length: 58181, dtype: object

# %%
### plot of sales accoring to the age category
Sales_agecategory=df.groupby('AgeCategory')['SalesAmount'].sum()
Sales_agecategory.plot(kind='pie',autopct='%0.0f%%',colors=['Magenta','Red'],labels=['Adult','Old'],shadow=True)
plt.title('Sales According to the Age Category',fontsize=20)
Sales_agecategory
# Out:
# AgeCategory
# Adult    1.441112e+07
# Old      1.488847e+07
# Name: SalesAmount, dtype: float64

# %% [markdown]
# ### This Shows us that the data contains no young and teen customers and the amount of money spend by the adult and the old people is alomost equal

# %%
Sales_product=df.groupby('ProductDescription')['SalesAmount'].sum().reset_index().sort_values(by='SalesAmount',ascending=False).head(10)
Sales_product
# Out:
#                                    ProductDescription   SalesAmount
# 24  Serious back-country riding. Perfect for all l...  7.927155e+06
# 30  This bike is ridden by race winners. Developed...  5.549897e+06
# 2   Alluminum-alloy frame provides a light, stiff ...  4.451260e+06
# 34  Travel in style and comfort. Designed for maxi...  2.989624e+06
# 8   Cross-train, race, or just socialize on a slee...  1.580220e+06
# 22  Same technology as all of our Road series bike...  1.514622e+06
# 31  Top-of-the-line competition mountain bike. Per...  1.337721e+06
# 9   Entry level adult bike; offers a comfortable r...  7.792056e+05
# 37  Value-priced bike with many features of our to...  6.453795e+05
# 27  The plush custom saddle keeps you riding all d...  4.519242e+05

# %%
### explort data for making a dash board
df.to_csv(r'C:\Users\dell\Desktop\data sets\BudgetSalesAnalysis.csv',index=False)

# %% [markdown]
# ## Conclusion: Most sales are made by people above 40 yrs of age based in U.S having annual income between range of 35000-80000 who comes from professional background with a bachlores eduation with 0 or 1 childrens .Also the most SalesAmount comes in the year of 2016 from  Bikes(Road Bikes).
